# %%
from gwpy.timeseries import TimeSeries
import pandas as pd
import numpy as np

# %%
#define parameters
#start_time = 1262217618 #Jan 5-12, 2020
start_time = 1263513618 #Jan 20-27, 2020
duration = 24*3600*8
channels = ['ETMX_Z','ITMY_Z','ETMY_Z','ETMX_X','ITMY_Y','ETMY_Y']

# %%
# %%time
#get time series in microseismic band ground motion
channelRMS = []
for chn in channels:
    chname = 'L1:ISI-GND_STS_' + chn + '_BLRMS_30M_100M.max'
    data = TimeSeries.find(chname, start_time, start_time + duration, frametype ='L1_M', verbose=True)
    channelRMS.append(data.value)
# Out:
# Reading L1_M frames: |          | 0/193 (  0%) ETA ?
#
#
#
#
#
#
#
#
# Reading L1_M frames: |          | 0/193 (  0%) ETA ?
#
#
#
#
#
#
#
#
# Reading L1_M frames: |          | 1/193 (  1%) ETA 03:45
#
#
#
#
#
#
#
#
# Reading L1_M frames: |          | 2/193 (  1%) ETA 03:42
#
#
#
#
#
#
#
#
# Reading L1_M frames: |▏         | 3/193 (  2%) ETA 03:27
#
#
#
#
#
#
#
#
# Reading L1_M frames: |▏         | 4/193 (  2%) ETA 03:06
#
#
#
#
#
#
#
#
# Reading L1_M frames: |▎         | 5/193 (  3%) ETA 02:48
#
#
#
#
#
#
#
#
# Reading L1_M frames: |▎         | 6/193 (  3%) ETA 02:49
#
#
#
#
#
#
#
#
# Reading L1_M frames: |▎         | 7/193 (  4%) ETA 02:46
#
#
#
#
#
#
#
#
# Reading L1_M frames: |▍         | 8/193 (  4%) ETA 02:37
#
#
#
#
#
#
#
#
# Reading L1_M frames: |▍         | 9/193 (  5%) ETA 05:05
#
#
#
#
#
#
#
#
# Reading L1_M frames: |▌         | 10/193 (  5%) ETA 04:10
#
#
#
#
#
#
#
#
# Reading L1_M frames: |▌         | 11/193 (  6%) ETA 03:43
#
#
#
#
#
#
#
#
# ...

# %%
#store data #eq = "earthquake"
eqdata = pd.DataFrame(np.transpose(channelRMS), columns = [channels])
eqdata
# Out:
#           ETMX_Z     ITMY_Z     ETMY_Z      ETMX_X      ITMY_Y      ETMY_Y
# 0      50.137260  49.836582  45.976494  121.932457  122.854012  135.403564
# 1      50.117844  50.251949  46.277668  132.944504  127.865021  140.410233
# 2      43.816895  43.237762  42.535404  131.884216  132.472717  139.069901
# 3      39.420170  39.245247  42.212402  115.584953  141.903900  143.475616
# 4      44.234486  43.593620  49.574291  130.762680  151.941437  144.863312
# 5      53.684589  49.925980  55.012363  147.332916  150.133591  141.130600
# 6      53.130814  49.548470  54.772079  145.737854  137.423096  132.702988
# 7      51.930283  47.715046  51.268909  131.425766  132.645126  130.437469
# 8      47.098515  46.778774  48.855499  148.442368  125.936066  126.504730
# 9      46.503853  43.754025  46.776962  152.136993  135.251373  124.527779
# 10     45.434563  41.343548  44.464531  142.523544  129.410324  123.046364
# ...

# %%
#save to csv #keep date and frequency in file name
eqdata.to_csv("eqdata_jan20-27_30M_100M.csv")

# %%
# %%time
#find time series for lockbit data
lockstate = []
lockbit_ts = TimeSeries.find('L1:GRD-ISC_LOCK_STATE_N.min',start_time, start_time + duration, frametype ='L1_M', verbose=True)
lockstate.append(lockbit_ts.value)
# Out:
# Reading L1_M frames: |          | 0/193 (  0%) ETA ?
#
#
#
#
#
#
#
# Reading L1_M frames: |          | 0/193 (  0%) ETA ?
#
#
#
#
#
#
#
# Reading L1_M frames: |          | 1/193 (  1%) ETA 04:17
#
#
#
#
#
#
#
# Reading L1_M frames: |          | 2/193 (  1%) ETA 04:18
#
#
#
#
#
#
#
# Reading L1_M frames: |▏         | 3/193 (  2%) ETA 04:57
#
#
#
#
#
#
#
# Reading L1_M frames: |▏         | 4/193 (  2%) ETA 04:32
#
#
#
#
#
#
#
# Reading L1_M frames: |▎         | 5/193 (  3%) ETA 04:30
#
#
#
#
#
#
#
# Reading L1_M frames: |▎         | 6/193 (  3%) ETA 04:31
#
#
#
#
#
#
#
# Reading L1_M frames: |▎         | 7/193 (  4%) ETA 05:11
#
#
#
#
#
#
#
# Reading L1_M frames: |▍         | 8/193 (  4%) ETA 05:15
#
#
#
#
#
#
#
# Reading L1_M frames: |▍         | 9/193 (  5%) ETA 05:02
#
#
#
#
#
#
#
# Reading L1_M frames: |▌         | 10/193 (  5%) ETA 04:46
#
#
#
#
#
#
#
# Reading L1_M frames: |▌         | 11/193 (  6%) ETA 04:49
#
#
#
#
#
#
#
# ...

# %%
#store data #lb = "lockbit"
lbdata = pd.DataFrame(np.transpose(lockstate)) #columns = [channels]
lbdata
# Out:
#             0
# 0        10.0
# 1        10.0
# 2        10.0
# 3        10.0
# 4        10.0
# 5        10.0
# 6        10.0
# 7        10.0
# 8        10.0
# 9        10.0
# 10       10.0
# 11       10.0
# 12       10.0
# 13       10.0
# 14       10.0
# 15       10.0
# 16       10.0
# 17       10.0
# 18       10.0
# 19       10.0
# 20       10.0
# 21       10.0
# 22       10.0
# 23       10.0
# 24       10.0
# 25       10.0
# 26       10.0
# 27       10.0
# 28       10.0
# 29       10.0
# ...       ...
# 11550  2000.0
# 11551  2000.0
# 11552  2000.0
# 11553  2000.0
# 11554  2000.0
# 11555  2000.0
# 11556  2000.0
# 11557  2000.0
# 11558  2000.0
# 11559  2000.0
# 11560  2000.0
# 11561  2000.0
# 11562  2000.0
# 11563  2000.0
# 11564  2000.0
# 11565  2000.0
# 11566  2000.0
# 11567  2000.0
# 11568  2000.0
# 11569  2000.0
# 11570  2000.0
# 11571  2000.0
# 11572  2000.0
# 11573  2000.0
# 11574  2000.0
# 11575  2000.0
# 11576  2000.0
# 11577  2000.0
# 11578  2000.0
# 11579  2000.0
#
# ...

# %%
#save to csv
lbdata.to_csv("lbdata_jan20-27.csv")
